# %%
#2. SIMPLE TEXT CLASSIFICATION 
def gender_features(word):
    return{'last_letter': word[-1]}

# %%
gender_features('Obama')
# Out:
# {'last_letter': 'a'}

# %%
from nltk.corpus import names

# %%
#names.words()
#print(len(names.words()))
labeled_names = ([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])
import random
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Anatol', 'male'),
#  ('Antonina', 'female'),
#  ('Arda', 'female'),
#  ('Legra', 'female'),
#  ('Margarita', 'female'),
#  ('Von', 'male'),
#  ('Nilson', 'male'),
#  ('Olle', 'male'),
#  ('Sophronia', 'female'),
#  ('Tish', 'female'),
#  ('Clio', 'female'),
#  ('Lurleen', 'female'),
#  ('Erminie', 'female'),
#  ('Jermain', 'male'),
#  ('Lorianna', 'female'),
#  ('Kirstin', 'female'),
#  ('Lynn', 'male'),
#  ('Purcell', 'male'),
#  ('Eleanore', 'female'),
#  ('Teddy', 'male'),
#  ('Farand', 'female'),
#  ('Manny', 'male'),
#  ('Myke', 'male'),
#  ('Audre', 'female'),
#  ('Hudson', 'male'),
#  ('Tricia', 'female'),
#  ('Goldie', 'female'),
#  ('Ileane', 'female'),
#  ('Tiena', 'female'),
#  ('Sarge', 'male'),
#  ('Aline', 'female'),
#  ('Annecorinne', 'female'),
#  ('Lorelle', 'female'),
#  ('Shir', 'female'),
#  ('Pincas', 'male'),
#  ('Cecil', 'male'),
#  ('Lesya', 'female'),
#  ('Toni', 'female'),
#  ('Lindsy', 'female'),
#  ('Hetty', 'female'),
#  ('Thorpe', 'male'),
#  ('Welby', 'male'),
#  ('Mamie', 'female'),
#  ('Daisy', 'female'),
#  ('Sari', 'female'),
#  ('Silvio', 'male'),
#  ('Virgil', 'male'),
#  ('Tami', 'female'),
#  ('Neron', 'male'),
#  ('Mercedes', 'female'),
#  ('Anurag', 'male'),
#  ('Blondie', 'female'),
#  ('Olympe', 'female'),
#  ('Arlene', 'female'),
#  ('Lorne', 'female'),
#  ('Stephenie', 'female'),
#  ('Frazier', 'male'),
#  ('Peg', 'female'),
#  ('Marinna', 'female'),
#  ('Hatti', 'female'),
#  ('Nikita', 'male'),
#  ('Delaney', 'female'),
#  ('Jordain', 'female'),
#  ('Elizabet', 'female'),
#  ('Savina', 'female'),
#  ('Minette', 'female'),
#  ('Poppy', 'female'),
#  ('Kassia', 'female'),
#  ('Elinore', 'female'),
#  ('Opalina', 'female'),
#  ('Corliss', 'female'),
#  ('Lorie', 'female'),
#  ('Ron', 'male'),
#  ('Neely', 'female'),
#  ('Wells', 'male'),
#  ('Wilton', 'male'),
#  ('Nelie', 'female'),
#  ('Merlin', 'male'),
#  ('Trace', 'female'),
#  ('Linnet', 'female'),
#  ('Tiffie', 'female'),
#  ('Rice', 'male'),
#  ('Bev', 'female'),
#  ('Rena', 'female'),
#  ('Stern', 'male'),
#  ('Maurise', 'male'),
#  ('Jake', 'male'),
#  ('Anabelle', 'female'),
#  ('Jaquelyn', 'female'),
#  ('Sybilla', 'female'),
#  ('Ruperta', 'female'),
#  ('Isabella', 'female'),
#  ('Inessa', 'female'),
#  ('Hildagard', 'female'),
#  ('Obie', 'male'),
#  ('Honey', 'female'),
#  ('Parrnell', 'male'),
#  ('Dyann', 'female'),
#  ('Emery', 'male'),
#  ('Willey', 'male'),
#  ('Vassily', 'male'),
#  ('Adolphe', 'male'),
#  ('Doll', 'female'),
#  ('Veriee', 'female'),
#  ('Roth', 'male'),
#  ('Jeanette', 'female'),
#  ('Garp', 'male'),
#  ('Yank', 'male'),
#  ('Humbert', 'male'),
#  ('Koralle', 'female'),
#  ('Concettina', 'female'),
#  ('Leiah', 'female'),
#  ('Doro', 'female'),
#  ('Channa', 'female'),
#  ('Waverly', 'male'),
#  ('Inge', 'female'),
#  ('Nevile', 'male'),
#  ('Richard', 'male'),
#  ('Mirabella', 'female'),
#  ('Pattie', 'female'),
#  ('Ingunna', 'female'),
#  ('Hastings', 'male'),
#  ('Ray', 'male'),
#  ('Gwenette', 'female'),
#  ('Leticia', 'female'),
#  ('Giff', 'male'),
#  ('Heinz', 'male'),
#  ('Corenda', 'female'),
#  ('Pierre', 'male'),
#  ('Avrit', 'female'),
#  ('Way', 'male'),
#  ('Aylmer', 'male'),
#  ('Neala', 'female'),
#  ('Florice', 'female'),
#  ('Ilysa', 'female'),
#  ('Roz', 'female'),
#  ('Gene', 'female'),
#  ('Janus', 'male'),
#  ('Darth', 'male'),
#  ('Nahum', 'male'),
#  ('Isaak', 'male'),
#  ('Tomasina', 'female'),
#  ('Pearline', 'female'),
#  ('Joellen', 'female'),
#  ('Frederick', 'male'),
#  ('Denys', 'female'),
#  ('Vinny', 'female'),
#  ('Sascha', 'female'),
#  ('Bjorne', 'male'),
#  ('Arlina', 'female'),
#  ('Nari', 'female'),
#  ('Nate', 'male'),
#  ('Gayle', 'female'),
#  ('Marian', 'female'),
#  ('Sibelle', 'female'),
#  ('Calhoun', 'male'),
#  ('Marigold', 'female'),
#  ('Guenna', 'female'),
#  ('Stanleigh', 'male'),
#  ('Sydney', 'female'),
#  ('Cassandry', 'female'),
#  ('Ofelia', 'female'),
#  ('Hallam', 'male'),
#  ('Tandie', 'female'),
#  ('Wyndham', 'male'),
#  ('Michelle', 'female'),
#  ('Pepita', 'female'),
#  ('Hamish', 'male'),
#  ('Mersey', 'female'),
#  ('Iago', 'male'),
#  ('Terri', 'male'),
#  ('Coralie', 'female'),
#  ('Percival', 'male'),
#  ('Ferinand', 'male'),
#  ('Geoffrey', 'male'),
#  ('Lorene', 'female'),
#  ('Silvan', 'male'),
#  ('Abagael', 'female'),
#  ('Jenilee', 'female'),
#  ('Fletcher', 'male'),
#  ('Hazel', 'female'),
#  ('Raynor', 'male'),
#  ('Joni', 'female'),
#  ('Lottie', 'female'),
#  ('Minna', 'female'),
#  ('Hilton', 'male'),
#  ('Wolfram', 'male'),
#  ('Tracey', 'male'),
#  ('Giovanni', 'male'),
#  ('Barny', 'male'),
#  ('Dorthy', 'female'),
#  ('Rina', 'female'),
#  ('Lindie', 'female'),
#  ('Mohamad', 'male'),
#  ('Glori', 'female'),
#  ('Kerrin', 'female'),
#  ('Cristionna', 'female'),
#  ('Anna-Diane', 'female'),
#  ('Patel', 'male'),
#  ('Noell', 'female'),
#  ('Shaun', 'female'),
#  ('Zilvia', 'female'),
#  ('Cody', 'male'),
#  ('Oralla', 'female'),
#  ('Corinne', 'female'),
#  ('Alfonse', 'male'),
#  ('Karla', 'female'),
#  ('Emmett', 'male'),
#  ('Halette', 'female'),
#  ('Shurwood', 'male'),
#  ('Georg', 'male'),
#  ('Hervey', 'male'),
#  ('Onida', 'female'),
#  ('Maynord', 'male'),
#  ('Britaney', 'female'),
#  ('Lilyan', 'female'),
#  ('Sullivan', 'male'),
#  ('Wake', 'male'),
#  ('Chris', 'male'),
#  ('Carlton', 'male'),
#  ('Hirsch', 'male'),
#  ('Mendel', 'male'),
#  ('Latisha', 'female'),
#  ('Genny', 'female'),
#  ('Denna', 'female'),
#  ('Alysia', 'female'),
#  ('Cat', 'female'),
#  ('Lianna', 'female'),
#  ('Marthe', 'female'),
#  ('Gerry', 'female'),
#  ('Dorella', 'female'),
#  ('Piper', 'female'),
#  ('Shandra', 'female'),
#  ('Valentina', 'female'),
#  ('Binky', 'male'),
#  ('Carley', 'female'),
#  ('Charmaine', 'female'),
#  ('Nicolle', 'female'),
#  ('Flemming', 'male'),
#  ('Clemence', 'female'),
#  ('Clo', 'female'),
#  ('Annalena', 'female'),
#  ('Artur', 'male'),
#  ('Christian', 'female'),
#  ('Veronica', 'female'),
#  ('Quentin', 'male'),
#  ('Berchtold', 'male'),
#  ('Norry', 'female'),
#  ('Ainsley', 'female'),
#  ('Chalmers', 'male'),
#  ('Chelsae', 'female'),
#  ('Osbourne', 'male'),
#  ('Pennie', 'female'),
#  ('Cristy', 'female'),
#  ('Al', 'male'),
#  ('Hulda', 'female'),
#  ('Christen', 'female'),
#  ('Mercie', 'female'),
#  ('Arabella', 'female'),
#  ('Jacquelyn', 'female'),
#  ('Ehud', 'male'),
#  ('Arie', 'male'),
#  ('Austin', 'male'),
#  ('Ronny', 'male'),
#  ('Town', 'male'),
#  ('Hatty', 'female'),
#  ('Gilli', 'female'),
#  ('Danie', 'male'),
#  ('Burt', 'male'),
#  ('Ulrike', 'female'),
#  ('Tucker', 'male'),
#  ('Sinead', 'female'),
#  ('Mohan', 'male'),
#  ('Penny', 'male'),
#  ('Trixy', 'female'),
#  ('Amadeus', 'male'),
#  ('Johan', 'male'),
#  ('Ignaz', 'male'),
#  ('Ellynn', 'female'),
#  ('Caro', 'female'),
#  ('Ivan', 'male'),
#  ('Wally', 'male'),
#  ('Cleopatra', 'female'),
#  ('Tiebout', 'male'),
#  ('Chadd', 'male'),
#  ('Bettye', 'female'),
#  ('Harrison', 'male'),
#  ('Corry', 'female'),
#  ('Meir', 'male'),
#  ('Harriott', 'female'),
#  ('Aeriell', 'female'),
#  ('Del', 'female'),
#  ('Montgomery', 'male'),
#  ('Karina', 'female'),
#  ('Cassandra', 'female'),
#  ('Edee', 'female'),
#  ('Aurora', 'female'),
#  ('Dyanna', 'female'),
#  ('Derk', 'male'),
#  ('Francesmary', 'female'),
#  ('Theressa', 'female'),
#  ('Bishop', 'male'),
#  ('Matt', 'male'),
#  ('Phylys', 'female'),
#  ('Noelle', 'female'),
#  ('Udale', 'male'),
#  ('Delinda', 'female'),
#  ('Ingemar', 'male'),
#  ('Julina', 'female'),
#  ('Colly', 'female'),
#  ('Dalton', 'male'),
#  ('Wang', 'male'),
#  ('Mohammed', 'male'),
#  ('Herbie', 'male'),
#  ('Hasty', 'male'),
#  ('Vanda', 'female'),
#  ('Fara', 'female'),
#  ('Harman', 'male'),
#  ('Torrence', 'male'),
#  ('Vergil', 'male'),
#  ('Harley', 'male'),
#  ('Penrod', 'male'),
#  ('Ardra', 'female'),
#  ('Rosabella', 'female'),
#  ('Morly', 'male'),
#  ('Laetitia', 'female'),
#  ('Lory', 'female'),
#  ('Claudio', 'male'),
#  ('Jeramie', 'male'),
#  ('Harvey', 'male'),
#  ('Sunshine', 'female'),
#  ('Prentice', 'male'),
#  ('Tildie', 'female'),
#  ('Martie', 'female'),
#  ('Hank', 'male'),
#  ('Zea', 'female'),
#  ('Genevieve', 'female'),
#  ('Clare', 'female'),
#  ('Ginnie', 'female'),
#  ('Ferne', 'female'),
#  ('Carolynn', 'female'),
#  ('Aggi', 'female'),
#  ('Tre', 'male'),
#  ('Maya', 'female'),
#  ('Kelwin', 'male'),
#  ('Gratiana', 'female'),
#  ('Bertie', 'female'),
#  ('Hillary', 'female'),
#  ('Trevar', 'male'),
#  ('Melli', 'female'),
#  ('Barclay', 'male'),
#  ('Olenka', 'female'),
#  ('Royce', 'male'),
#  ('Frederico', 'male'),
#  ('Antoine', 'male'),
#  ('Florella', 'female'),
#  ('Elysia', 'female'),
#  ('Emili', 'female'),
#  ('Nicoli', 'female'),
#  ('Dewey', 'male'),
#  ('Pace', 'male'),
#  ('Gill', 'male'),
#  ('Kourtney', 'female'),
#  ('Darcy', 'female'),
#  ('Miran', 'female'),
#  ('Minda', 'female'),
#  ('Vibhu', 'male'),
#  ('Marit', 'female'),
#  ('Bendite', 'female'),
#  ('Murial', 'female'),
#  ('Felix', 'male'),
#  ('Vinni', 'female'),
#  ('Elwood', 'male'),
#  ('Jordan', 'male'),
#  ('Matty', 'female'),
#  ('Franky', 'female'),
#  ('Trip', 'male'),
#  ('Ilka', 'female'),
#  ('Toinette', 'female'),
#  ('Noemi', 'female'),
#  ('Damien', 'male'),
#  ('Claudie', 'female'),
#  ('Pembroke', 'male'),
#  ('Tyler', 'male'),
#  ('Chevy', 'male'),
#  ('Aubree', 'female'),
#  ('Bonnee', 'female'),
#  ('Joceline', 'female'),
#  ('Dante', 'male'),
#  ('Anjanette', 'female'),
#  ('Piggy', 'male'),
#  ('Chris', 'female'),
#  ('Trudy', 'female'),
#  ('Rodolphe', 'male'),
#  ('Bekki', 'female'),
#  ('Misha', 'female'),
#  ('Brietta', 'female'),
#  ('Emalee', 'female'),
#  ('Dulcine', 'female'),
#  ('Lawrence', 'male'),
#  ('Adlai', 'male'),
#  ('Dianna', 'female'),
#  ('Ardath', 'female'),
#  ('Sherwynd', 'male'),
#  ('Voltaire', 'male'),
#  ('Laryssa', 'female'),
#  ('Tani', 'female'),
#  ('Pryce', 'male'),
#  ('Una', 'female'),
#  ('Larine', 'female'),
#  ('Rosabel', 'female'),
#  ('Nitin', 'female'),
#  ('Madalyn', 'female'),
#  ('Zed', 'male'),
#  ('Leila', 'female'),
#  ('Augie', 'male'),
#  ('Zeb', 'male'),
#  ('Ainslie', 'female'),
#  ('Huntington', 'male'),
#  ('Meira', 'female'),
#  ('Euphemia', 'female'),
#  ('Mirabelle', 'female'),
#  ('Tansy', 'female'),
#  ('Sapphira', 'female'),
#  ('Phillis', 'female'),
#  ('Creighton', 'male'),
#  ('Yettie', 'female'),
#  ('Ty', 'male'),
#  ('Peggi', 'female'),
#  ('Helene', 'female'),
#  ('Obadias', 'male'),
#  ('Lisandra', 'female'),
#  ('Madella', 'female'),
#  ('Susanne', 'female'),
#  ('Valaria', 'female'),
#  ('Petr', 'male'),
#  ('Ermengarde', 'female'),
#  ('Judith', 'female'),
#  ('Alain', 'male'),
#  ('Zeus', 'male'),
#  ('Lissi', 'female'),
#  ('Jakob', 'male'),
#  ('Noach', 'male'),
#  ('Tootsie', 'female'),
#  ('Brina', 'female'),
#  ('Rudie', 'male'),
#  ('Allie', 'male'),
#  ('Martin', 'male'),
#  ('Darlene', 'female'),
#  ('Will', 'male'),
#  ('Cob', 'male'),
#  ('Merrily', 'female'),
#  ('Tanney', 'male'),
#  ('Elianore', 'female'),
#  ('Lazare', 'male'),
#  ('Cathee', 'female'),
#  ('Kristal', 'female'),
#  ('Joachim', 'male'),
#  ('Aubrie', 'female'),
#  ('Herbert', 'male'),
#  ('Tess', 'female'),
#  ('Adrick', 'male'),
#  ('Dodie', 'female'),
#  ('Reine', 'female'),
#  ('Licha', 'female'),
#  ('Mason', 'male'),
#  ('Celle', 'female'),
#  ('Midge', 'female'),
#  ('Chantalle', 'female'),
#  ('Rozele', 'female'),
#  ('Ely', 'male'),
#  ('Storm', 'female'),
#  ('Rachele', 'female'),
#  ('Gabriella', 'female'),
#  ('Sheffield', 'male'),
#  ('Sallyann', 'female'),
#  ('Ellissa', 'female'),
#  ('Mellissa', 'female'),
#  ('Sukey', 'female'),
#  ('Martie', 'male'),
#  ('Louisa', 'female'),
#  ('Robb', 'male'),
#  ('Udall', 'male'),
#  ('Darryl', 'male'),
#  ('Aurore', 'female'),
#  ('Fred', 'male'),
#  ('Sephira', 'female'),
#  ('Frayda', 'female'),
#  ('Erda', 'female'),
#  ('Gavra', 'female'),
#  ('Brynn', 'female'),
#  ('Harlan', 'male'),
#  ('Errol', 'male'),
#  ('Katharyn', 'female'),
#  ('Woochang', 'male'),
#  ('Micaela', 'female'),
#  ('Xever', 'male'),
#  ('Hayden', 'male'),
#  ('Case', 'male'),
#  ('Tana', 'female'),
#  ('Angus', 'male'),
#  ('Srinivas', 'male'),
#  ('Giraud', 'male'),
#  ('Raleigh', 'male'),
#  ('Ibby', 'female'),
#  ('Lemmie', 'male'),
#  ('Andros', 'male'),
#  ('Kerianne', 'female'),
#  ('Annabella', 'female'),
#  ('Darian', 'male'),
#  ('Wood', 'male'),
#  ('Grier', 'female'),
#  ('Mort', 'male'),
#  ('Angelica', 'female'),
#  ('Donnajean', 'female'),
#  ('Iolande', 'female'),
#  ('Kaitlyn', 'female'),
#  ('Hebert', 'male'),
#  ('Kiele', 'female'),
#  ('Emmy', 'female'),
#  ('Gratia', 'female'),
#  ('Lolly', 'female'),
#  ('Ibrahim', 'male'),
#  ('Gertie', 'female'),
#  ('Marina', 'female'),
#  ('Lona', 'female'),
#  ('Willi', 'male'),
#  ('Pail', 'male'),
#  ('Dorry', 'female'),
#  ('Willem', 'male'),
#  ('Jeane', 'female'),
#  ('Junie', 'female'),
#  ('Kelcey', 'female'),
#  ('Kalila', 'female'),
#  ('Nelli', 'female'),
#  ('Verena', 'female'),
#  ('Anne-Marie', 'female'),
#  ('Grethel', 'female'),
#  ('Clarence', 'male'),
#  ('Elita', 'female'),
#  ('Guglielma', 'female'),
#  ('Truman', 'male'),
#  ('Colline', 'female'),
#  ('Pete', 'male'),
#  ('Prudence', 'female'),
#  ('Jobye', 'female'),
#  ('Krista', 'female'),
#  ('Erinna', 'female'),
#  ('Webster', 'male'),
#  ('Gladi', 'female'),
#  ('Delly', 'female'),
#  ('Dalenna', 'female'),
#  ('Pearl', 'female'),
#  ('Aharon', 'male'),
#  ('Chrysler', 'female'),
#  ('Samuela', 'female'),
#  ('Junette', 'female'),
#  ('Margette', 'female'),
#  ('Northrop', 'male'),
#  ('Trenna', 'female'),
#  ('Carmelita', 'female'),
#  ('Abbot', 'male'),
#  ('Letta', 'female'),
#  ('Cassie', 'female'),
#  ('Gardner', 'male'),
#  ('Ulla', 'female'),
#  ('Alex', 'male'),
#  ('Kathye', 'female'),
#  ('Gwyn', 'female'),
#  ('Sabrina', 'female'),
#  ('Vera', 'female'),
#  ('Margot', 'female'),
#  ('Maiga', 'female'),
#  ('Viole', 'female'),
#  ('Augustina', 'female'),
#  ('Evangelin', 'female'),
#  ('Peirce', 'male'),
#  ('Carlyle', 'male'),
#  ('Perry', 'male'),
#  ('Brenn', 'female'),
#  ('Hilliary', 'female'),
#  ('Kerry', 'female'),
#  ('Marven', 'male'),
#  ('Brandais', 'female'),
#  ('Isador', 'male'),
#  ('Lucas', 'male'),
#  ('Sonia', 'female'),
#  ('Isador', 'female'),
#  ('Carol', 'female'),
#  ('Freddi', 'female'),
#  ('Immanuel', 'male'),
#  ('Sybil', 'female'),
#  ('Vladamir', 'male'),
#  ('Gunther', 'male'),
#  ('Rosemaria', 'female'),
#  ('Jodie', 'male'),
#  ('Dan', 'male'),
#  ('Reena', 'female'),
#  ('Charin', 'female'),
#  ('Raimund', 'male'),
#  ('Rafaela', 'female'),
#  ('Lavinie', 'female'),
#  ('Gregg', 'male'),
#  ('Anna', 'female'),
#  ('Korney', 'female'),
#  ('Helen-Elizabeth', 'female'),
#  ('Marlow', 'male'),
#  ('Serge', 'male'),
#  ('Cameron', 'male'),
#  ('Bob', 'male'),
#  ('Wendy', 'female'),
#  ('Lisette', 'female'),
#  ('Ketty', 'female'),
#  ('Jocelyne', 'female'),
#  ('Marie', 'female'),
#  ('Noreen', 'female'),
#  ('Demetris', 'male'),
#  ('Martelle', 'female'),
#  ('Nisa', 'female'),
#  ('Betsey', 'female'),
#  ('Quiggly', 'male'),
#  ('Netti', 'female'),
#  ('Ursula', 'female'),
#  ('Roosevelt', 'male'),
#  ('Rutledge', 'male'),
#  ('Angel', 'female'),
#  ('Andrzej', 'male'),
#  ('Hogan', 'male'),
#  ('Townsend', 'male'),
#  ('Iggy', 'male'),
#  ('Tersina', 'female'),
#  ('Cornelia', 'female'),
#  ('Evvie', 'female'),
#  ('Albertine', 'female'),
#  ('Melania', 'female'),
#  ('Roderigo', 'male'),
#  ('Ora', 'female'),
#  ('Brittney', 'female'),
#  ('Konstance', 'female'),
#  ('Arlyne', 'female'),
#  ('Alfie', 'male'),
#  ('Greggory', 'male'),
#  ('Mollie', 'female'),
#  ('Myron', 'male'),
#  ('Hannis', 'female'),
#  ('Katrinka', 'female'),
#  ('Ketti', 'female'),
#  ('Ivett', 'female'),
#  ('Geraldo', 'male'),
#  ('Moishe', 'male'),
#  ('Maggi', 'female'),
#  ('Dora', 'female'),
#  ('Cordula', 'female'),
#  ('Karalynn', 'female'),
#  ('Terrel', 'male'),
#  ('Wilburt', 'male'),
#  ('Robbi', 'female'),
#  ('Salim', 'male'),
#  ('Plato', 'male'),
#  ('Job', 'male'),
#  ('Zary', 'male'),
#  ('Duffie', 'male'),
#  ('Babette', 'female'),
#  ('Clarita', 'female'),
#  ('Cathleen', 'female'),
#  ('Kellen', 'male'),
#  ('Germain', 'female'),
#  ('Travers', 'male'),
#  ('Liana', 'female'),
#  ('Godfry', 'male'),
#  ('Cal', 'male'),
#  ('Valerie', 'female'),
#  ('Reid', 'male'),
#  ('Dollie', 'female'),
#  ('Rik', 'male'),
#  ('Kellia', 'female'),
#  ('Marrilee', 'female'),
#  ('Jon', 'male'),
#  ('Georgia', 'male'),
#  ('Muire', 'female'),
#  ('Bary', 'male'),
#  ('Cassondra', 'female'),
#  ('Dorolice', 'female'),
#  ('Andie', 'female'),
#  ('Marcel', 'male'),
#  ('Anallese', 'female'),
#  ('Irwin', 'male'),
#  ('Jacquelynn', 'female'),
#  ('Yalonda', 'female'),
#  ('Lauri', 'female'),
#  ('Reynard', 'male'),
#  ('Jourdan', 'female'),
#  ('Lorri', 'female'),
#  ('Gayleen', 'female'),
#  ('Claudius', 'male'),
#  ('Harvie', 'male'),
#  ('Marianna', 'female'),
#  ('Saba', 'female'),
#  ('Karry', 'female'),
#  ('Winnah', 'female'),
#  ('Hanford', 'male'),
#  ('Ed', 'male'),
#  ('Yehudi', 'male'),
#  ('Harcourt', 'male'),
#  ('Marilu', 'male'),
#  ('Janene', 'female'),
#  ('Rollo', 'male'),
#  ('Cindy', 'female'),
#  ('Aleen', 'female'),
#  ('Connie', 'female'),
#  ('Wenda', 'female'),
#  ('Norris', 'male'),
#  ('Noland', 'male'),
#  ('Stacia', 'female'),
#  ('Lynne', 'female'),
#  ('Rogers', 'male'),
#  ('Janean', 'female'),
#  ('Anastasie', 'female'),
#  ('Michaelina', 'female'),
#  ('Hobart', 'male'),
#  ('Jefry', 'male'),
#  ('Yehudit', 'female'),
#  ('Venkat', 'male'),
#  ('Patrica', 'female'),
#  ('Kathleen', 'female'),
#  ('Gail', 'female'),
#  ('Mitchael', 'male'),
#  ('Irvine', 'male'),
#  ('Uli', 'male'),
#  ('Johnette', 'female'),
#  ('Tharen', 'male'),
#  ('Rafe', 'male'),
#  ('Zachary', 'male'),
#  ('Cristie', 'female'),
#  ('Dea', 'female'),
#  ('Luna', 'female'),
#  ('Brady', 'male'),
#  ('Beryl', 'female'),
#  ('Ann-Mari', 'female'),
#  ('Jacob', 'male'),
#  ('Kamilah', 'female'),
#  ('Daria', 'female'),
#  ('Elonore', 'female'),
#  ('Hedda', 'female'),
#  ('Elizabeth', 'female'),
#  ('Roselia', 'female'),
#  ('Jemie', 'female'),
#  ('Barrett', 'male'),
#  ('Flem', 'male'),
#  ('Mariann', 'female'),
#  ('Philippe', 'female'),
#  ('Karolina', 'female'),
#  ('Aidan', 'female'),
#  ('Jerry', 'male'),
#  ('Carlie', 'female'),
#  ('Aube', 'male'),
#  ('Marchall', 'male'),
#  ('Olimpia', 'female'),
#  ('Kimberlee', 'female'),
#  ('Misti', 'female'),
#  ('Mikel', 'male'),
#  ('Krissie', 'female'),
#  ('Joli', 'female'),
#  ('Agneta', 'female'),
#  ('Miranda', 'female'),
#  ('Laney', 'female'),
#  ('Mehetabel', 'female'),
#  ('Kingsly', 'male'),
#  ('Francisco', 'male'),
#  ('Kath', 'female'),
#  ('Fabio', 'male'),
#  ('Whitney', 'male'),
#  ('Letti', 'female'),
#  ('Norrie', 'female'),
#  ('Zita', 'female'),
#  ('Nana', 'female'),
#  ('Neil', 'male'),
#  ('Tyson', 'male'),
#  ('Rahel', 'female'),
#  ('Kelila', 'female'),
#  ('Sarene', 'female'),
#  ('Alec', 'male'),
#  ('Thomasine', 'female'),
#  ('Lilah', 'female'),
#  ('Olwen', 'female'),
#  ('Antin', 'male'),
#  ('Hetti', 'female'),
#  ('Aurelie', 'female'),
#  ('Demosthenis', 'male'),
#  ('Camille', 'female'),
#  ('Rosina', 'female'),
#  ('Esmeralda', 'female'),
#  ('Keren', 'female'),
#  ('Nona', 'female'),
#  ('Chan', 'male'),
#  ('Tailor', 'male'),
#  ('Gui', 'female'),
#  ('Nady', 'female'),
#  ('Alameda', 'female'),
#  ('Holly-Anne', 'female'),
#  ('Lesley', 'male'),
#  ('Jyoti', 'female'),
#  ('Rori', 'female'),
#  ('Ettie', 'female'),
#  ('Fanya', 'female'),
#  ('Ramona', 'female'),
#  ('Dulcy', 'female'),
#  ('Neal', 'male'),
#  ('Dorit', 'female'),
#  ('Mariellen', 'female'),
#  ('Ichabod', 'male'),
#  ('Thalia', 'female'),
#  ('Harris', 'male'),
#  ('Dot', 'female'),
#  ('Skelly', 'male'),
#  ('Minerva', 'female'),
#  ('Darwin', 'male'),
#  ('Sophi', 'female'),
#  ('Magdalena', 'female'),
#  ('Natalina', 'female'),
#  ('Vince', 'male'),
#  ('Viviyan', 'female'),
#  ('Millisent', 'female'),
#  ('Gwendolyn', 'female'),
#  ('Kore', 'female'),
#  ('Vivyanne', 'female'),
#  ('JoAnne', 'female'),
#  ('Alastair', 'male'),
#  ('Waldon', 'male'),
#  ('Zachariah', 'male'),
#  ('Demeter', 'female'),
#  ('Teodoor', 'male'),
#  ('Vena', 'female'),
#  ('Torey', 'male'),
#  ('Fredra', 'female'),
#  ('Wini', 'female'),
#  ('Georgette', 'female'),
#  ('Lust', 'female'),
#  ('Corinna', 'female'),
#  ('Tad', 'male'),
#  ('Cheslie', 'female'),
#  ('Davina', 'female'),
#  ('Jerzy', 'male'),
#  ('Laurianne', 'female'),
#  ('Lucie', 'female'),
#  ('Ewart', 'male'),
#  ('Ronald', 'male'),
#  ('Aili', 'female'),
#  ('Bo', 'male'),
#  ('Rozina', 'female'),
#  ('Gwenneth', 'female'),
#  ('Rosette', 'female'),
#  ('Jean-Pierre', 'male'),
#  ('Madlin', 'female'),
#  ('Emile', 'male'),
#  ('Valeda', 'female'),
#  ('Bella', 'female'),
#  ('Eveleen', 'female'),
#  ('Sammie', 'male'),
#  ('Willy', 'male'),
#  ('Dorisa', 'female'),
#  ('Cherise', 'female'),
#  ('Briney', 'female'),
#  ('Krystyna', 'female'),
#  ('Adelaide', 'female'),
#  ('Constanta', 'female'),
#  ('Woodman', 'male'),
#  ('Maisie', 'female'),
#  ('Shane', 'female'),
#  ('Kevan', 'male'),
#  ('Emanuela', 'female'),
#  ('Burl', 'male'),
#  ('Jo-Anne', 'female'),
#  ('Steffane', 'female'),
#  ('Stillmann', 'male'),
#  ('Breanne', 'female'),
#  ('Weider', 'male'),
#  ('Goldina', 'female'),
#  ('Blair', 'female'),
#  ('Wallache', 'male'),
#  ('Anselma', 'female'),
#  ('Jerald', 'male'),
#  ('Sianna', 'female'),
#  ('Valentine', 'male'),
#  ('Wildon', 'male'),
#  ('Vance', 'male'),
#  ('Sheldon', 'male'),
#  ('Temp', 'male'),
#  ('Krishna', 'male'),
#  ('Nena', 'female'),
#  ('Ebeneser', 'male'),
#  ('Dorolisa', 'female'),
#  ('Evangeline', 'female'),
#  ('Othilia', 'female'),
#  ('Malva', 'female'),
#  ('Debra', 'female'),
#  ('Timothea', 'female'),
#  ('Geralda', 'female'),
#  ('Maud', 'female'),
#  ('Meggi', 'female'),
#  ('Enrico', 'male'),
#  ('Cloris', 'female'),
#  ('Tamas', 'male'),
#  ('Kirsti', 'female'),
#  ('Dorene', 'female'),
#  ('Sinclare', 'male'),
#  ('Alaa', 'male'),
#  ('Lucien', 'male'),
#  ('Leshia', 'female'),
#  ('Chloette', 'female'),
#  ('Durant', 'male'),
#  ('Tabbie', 'female'),
#  ('Aram', 'male'),
#  ('Eustacia', 'female'),
#  ('Eunice', 'female'),
#  ('Arly', 'female'),
#  ('Sasha', 'male'),
#  ('Anja', 'female'),
#  ('Sidonnie', 'female'),
#  ('Susi', 'female'),
#  ('Sussi', 'female'),
#  ('Grover', 'male'),
#  ('Warden', 'male'),
#  ('Fritz', 'male'),
#  ('Molly', 'female'),
#  ('Wileen', 'female'),
#  ('Mildrid', 'female'),
#  ('Bartie', 'male'),
#  ('Kraig', 'male'),
#  ('Charles', 'male'),
#  ('Mick', 'male'),
#  ('Fabrianne', 'female'),
#  ('Pierrette', 'female'),
#  ('Jewel', 'female'),
#  ('Raymund', 'male'),
#  ('Roxanne', 'female'),
#  ('Saul', 'male'),
#  ('Rob', 'male'),
#  ('Fifi', 'female'),
#  ('Ilse', 'female'),
#  ('Benton', 'male'),
#  ('Canada', 'female'),
#  ('Christiano', 'male'),
#  ('Thornton', 'male'),
#  ('Tam', 'male'),
#  ('Simeon', 'male'),
#  ('Margalo', 'female'),
#  ('Doralynne', 'female'),
#  ('Andriana', 'female'),
#  ('Blisse', 'female'),
#  ('Constantinos', 'male'),
#  ('Carlina', 'female'),
#  ('Zolly', 'male'),
#  ('Lanny', 'male'),
#  ('Dedra', 'female'),
#  ('Biddy', 'female'),
#  ('Catherine', 'female'),
#  ('Maddi', 'female'),
#  ('Terrill', 'male'),
#  ('Clayton', 'male'),
#  ('Bryana', 'female'),
#  ('Darcie', 'female'),
#  ('Ahmad', 'male'),
#  ('Crista', 'female'),
#  ('Arvy', 'male'),
#  ('Albatros', 'male'),
#  ('Bill', 'male'),
#  ('Abra', 'female'),
#  ('Simonette', 'female'),
#  ('Brock', 'male'),
#  ('Veronika', 'female'),
#  ('Evvy', 'female'),
#  ('Catherina', 'female'),
#  ('Loria', 'female'),
#  ('Arthur', 'male'),
#  ('Brynna', 'female'),
#  ('Luigi', 'male'),
#  ('Norine', 'female'),
#  ('Jeffrey', 'male'),
#  ('Samson', 'male'),
#  ('Aileen', 'female'),
#  ('Mufinella', 'female'),
#  ('Barris', 'male'),
#  ('Marylinda', 'female'),
#  ('Solly', 'male'),
#  ('Gaby', 'female'),
#  ('Kerri', 'female'),
#  ('Jeffry', 'male'),
#  ('Griffith', 'male'),
#  ('Aleece', 'female'),
#  ('Joyan', 'female'),
#  ('Raine', 'female'),
#  ('Alix', 'female'),
#  ('Amelita', 'female'),
#  ('Daile', 'female'),
#  ('Andonis', 'male'),
#  ('Meryl', 'male'),
#  ('Noble', 'male'),
#  ('Raphaela', 'female'),
#  ('Guthrey', 'male'),
#  ...]

# %%
import random 
random.shuffle(labeled_names)

# %%
train_set,test_set = featuresets[5000:],featuresets[:2000]
import nltk 
classifier = nltk.NaiveBayesClassifier.train(train_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eb8df687877e> in <module>
# ----> 1 train_set,test_set = featuresets[5000:],featuresets[:2000]
#       2 import nltk
#       3 classifier = nltk.NaiveBayesClassifier.train(train_set)
#
# NameError: name 'featuresets' is not defined

# %%
classifier.classify(gender_features('David'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e3bc0ccd26e0> in <module>
# ----> 1 classifier.classify(gender_features('David'))
#
# NameError: name 'classifier' is not defined

# %%
classifier.classify(gender_features('Obama '))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d79dc0052cd4> in <module>
# ----> 1 classifier.classify(gender_features('Obama '))
#
# NameError: name 'classifier' is not defined

# %%
classifier.classify(gender_features('Shanmukh '))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2ebcacbfefe0> in <module>
# ----> 1 classifier.classify(gender_features('Shanmukh '))
#
# NameError: name 'classifier' is not defined

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b41f4c2337e3> in <module>
# ----> 1 print(nltk.classify.accuracy(classifier,test_set))
#
# NameError: name 'nltk' is not defined

# %%
#3. count vectorizer 
from sklearn.feature_extraction.text import CountVectorizer 
vect = CountVectorizer(binary=True)
corpus = ["Hi this is natural langauage processing, jupyter "]

# %%
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vocab = vect.vocabulary_

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# hi:0
# is:1
# jupyter:2
# langauage:3
# natural:4
# processing:5
# this:6

# %%
print(vect.transform(["This is a good optical illusion "]).toarray())
# Out:
# [[0 1 0 0 0 0 1]]

# %%
print(vect.transform(["This is a good good optical illusion "]).toarray())
# Out:
# [[0 1 0 0 0 0 1]]

# %%
from nltk.corpus import names

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
#  'Aime',
#  'Aimee',
#  'Aimil',
#  'Aina',
#  'Aindrea',
#  'Ainslee',
#  'Ainsley',
#  'Ainslie',
#  'Ajay',
#  'Alaine',
#  'Alameda',
#  'Alana',
#  'Alanah',
#  'Alane',
#  'Alanna',
#  'Alayne',
#  'Alberta',
#  'Albertina',
#  'Albertine',
#  'Albina',
#  'Alecia',
#  'Aleda',
#  'Aleece',
#  'Aleecia',
#  'Aleen',
#  'Alejandra',
#  'Alejandrina',
#  'Alena',
#  'Alene',
#  'Alessandra',
#  'Aleta',
#  'Alethea',
#  'Alex',
#  'Alexa',
#  'Alexandra',
#  'Alexandrina',
#  'Alexi',
#  'Alexia',
#  'Alexina',
#  'Alexine',
#  'Alexis',
#  'Alfie',
#  'Alfreda',
#  'Ali',
#  'Alia',
#  'Alica',
#  'Alice',
#  'Alicea',
#  'Alicia',
#  'Alida',
#  'Alidia',
#  'Alina',
#  'Aline',
#  'Alis',
#  'Alisa',
#  'Alisha',
#  'Alison',
#  'Alissa',
#  'Alisun',
#  'Alix',
#  'Aliza',
#  'Alla',
#  'Alleen',
#  'Allegra',
#  'Allene',
#  'Alli',
#  'Allianora',
#  'Allie',
#  'Allina',
#  'Allis',
#  'Allison',
#  'Allissa',
#  'Allsun',
#  'Ally',
#  'Allyce',
#  'Allyn',
#  'Allys',
#  'Allyson',
#  'Alma',
#  'Almeda',
#  'Almeria',
#  'Almeta',
#  'Almira',
#  'Almire',
#  'Aloise',
#  'Aloisia',
#  'Aloysia',
#  'Alpa',
#  'Alta',
#  'Althea',
#  'Alvera',
#  'Alvina',
#  'Alvinia',
#  'Alvira',
#  'Alyce',
#  'Alyda',
#  'Alys',
#  'Alysa',
#  'Alyse',
#  'Alysia',
#  'Alyson',
#  'Alyss',
#  'Alyssa',
#  'Amabel',
#  'Amabelle',
#  'Amalea',
#  'Amalee',
#  'Amaleta',
#  'Amalia',
#  'Amalie',
#  'Amalita',
#  'Amalle',
#  'Amanda',
#  'Amandi',
#  'Amandie',
#  'Amandy',
#  'Amara',
#  'Amargo',
#  'Amata',
#  'Amber',
#  'Amberly',
#  'Ambrosia',
#  'Ambur',
#  'Ame',
#  'Amelia',
#  'Amelie',
#  'Amelina',
#  'Ameline',
#  'Amelita',
#  'Ami',
#  'Amie',
#  'Amity',
#  'Ammamaria',
#  'Amy',
#  'Ana',
#  'Anabel',
#  'Anabella',
#  'Anabelle',
#  'Anais',
#  'Analiese',
#  'Analise',
#  'Anallese',
#  'Anallise',
#  'Anastasia',
#  'Anastasie',
#  'Anastassia',
#  'Anatola',
#  'Andee',
#  'Andi',
#  'Andie',
#  'Andra',
#  'Andrea',
#  'Andreana',
#  'Andree',
#  'Andrei',
#  'Andria',
#  'Andriana',
#  'Andriette',
#  'Andromache',
#  'Andromeda',
#  'Andy',
#  'Anestassia',
#  'Anet',
#  'Anett',
#  'Anetta',
#  'Anette',
#  'Ange',
#  'Angel',
#  'Angela',
#  'Angele',
#  'Angelia',
#  'Angelica',
#  'Angelika',
#  'Angelina',
#  'Angeline',
#  'Angelique',
#  'Angelita',
#  'Angelle',
#  'Angie',
#  'Angil',
#  'Angy',
#  'Ania',
#  'Anica',
#  'Anissa',
#  'Anita',
#  'Anitra',
#  'Anja',
#  'Anjanette',
#  'Anjela',
#  'Ann',
#  'Ann-Mari',
#  'Ann-Marie',
#  'Anna',
#  'Anna-Diana',
#  'Anna-Diane',
#  'Anna-Maria',
#  'Annabal',
#  'Annabel',
#  'Annabela',
#  'Annabell',
#  'Annabella',
#  'Annabelle',
#  'Annadiana',
#  'Annadiane',
#  'Annalee',
#  'Annalena',
#  'Annaliese',
#  'Annalisa',
#  'Annalise',
#  'Annalyse',
#  'Annamari',
#  'Annamaria',
#  'Annamarie',
#  'Anne',
#  'Anne-Corinne',
#  'Anne-Mar',
#  'Anne-Marie',
#  'Annecorinne',
#  'Anneliese',
#  'Annelise',
#  'Annemarie',
#  'Annetta',
#  'Annette',
#  'Anni',
#  'Annice',
#  'Annie',
#  'Annissa',
#  'Annmaria',
#  'Annmarie',
#  'Annnora',
#  'Annora',
#  'Anny',
#  'Anselma',
#  'Ansley',
#  'Anstice',
#  'Anthe',
#  'Anthea',
#  'Anthia',
#  'Antoinette',
#  'Antonella',
#  'Antonetta',
#  'Antonia',
#  'Antonie',
#  'Antonietta',
#  'Antonina',
#  'Anya',
#  'Aphrodite',
#  'Appolonia',
#  'April',
#  'Aprilette',
#  'Ara',
#  'Arabel',
#  'Arabela',
#  'Arabele',
#  'Arabella',
#  'Arabelle',
#  'Arda',
#  'Ardath',
#  'Ardeen',
#  'Ardelia',
#  'Ardelis',
#  'Ardella',
#  'Ardelle',
#  'Arden',
#  'Ardene',
#  'Ardenia',
#  'Ardine',
#  'Ardis',
#  'Ardith',
#  'Ardra',
#  'Ardyce',
#  'Ardys',
#  'Ardyth',
#  'Aretha',
#  'Ariadne',
#  'Ariana',
#  'Arianne',
#  'Aridatha',
#  'Ariel',
#  'Ariela',
#  'Ariella',
#  'Arielle',
#  'Arlana',
#  'Arlee',
#  'Arleen',
#  'Arlen',
#  'Arlena',
#  'Arlene',
#  'Arleta',
#  'Arlette',
#  'Arleyne',
#  'Arlie',
#  'Arliene',
#  'Arlina',
#  'Arlinda',
#  'Arline',
#  'Arly',
#  'Arlyn',
#  'Arlyne',
#  'Aryn',
#  'Ashely',
#  'Ashlee',
#  'Ashleigh',
#  'Ashlen',
#  'Ashley',
#  'Ashli',
#  'Ashlie',
#  'Ashly',
#  'Asia',
#  'Astra',
#  'Astrid',
#  'Astrix',
#  'Atalanta',
#  'Athena',
#  'Athene',
#  'Atlanta',
#  'Atlante',
#  'Auberta',
#  'Aubine',
#  'Aubree',
#  'Aubrette',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Audi',
#  'Audie',
#  'Audra',
#  'Audre',
#  'Audrey',
#  'Audrie',
#  'Audry',
#  'Audrye',
#  'Audy',
#  'Augusta',
#  'Auguste',
#  'Augustina',
#  'Augustine',
#  'Aura',
#  'Aurea',
#  'Aurel',
#  'Aurelea',
#  'Aurelia',
#  'Aurelie',
#  'Auria',
#  'Aurie',
#  'Aurilia',
#  'Aurlie',
#  'Auroora',
#  'Aurora',
#  'Aurore',
#  'Austin',
#  'Austina',
#  'Austine',
#  'Ava',
#  'Aveline',
#  'Averil',
#  'Averyl',
#  'Avie',
#  'Avis',
#  'Aviva',
#  'Avivah',
#  'Avril',
#  'Avrit',
#  'Ayn',
#  'Bab',
#  'Babara',
#  'Babette',
#  'Babita',
#  'Babs',
#  'Bambi',
#  'Bambie',
#  'Bamby',
#  'Barb',
#  'Barbabra',
#  'Barbara',
#  'Barbara-Anne',
#  'Barbaraanne',
#  'Barbe',
#  'Barbee',
#  'Barbette',
#  'Barbey',
#  'Barbi',
#  'Barbie',
#  'Barbra',
#  'Barby',
#  'Bari',
#  'Barrie',
#  'Barry',
#  'Basia',
#  'Bathsheba',
#  'Batsheva',
#  'Bea',
#  'Beatrice',
#  'Beatrisa',
#  'Beatrix',
#  'Beatriz',
#  'Beau',
#  'Bebe',
#  'Becca',
#  'Becka',
#  'Becki',
#  'Beckie',
#  'Becky',
#  'Bee',
#  'Beilul',
#  'Beitris',
#  'Bekki',
#  'Bel',
#  'Belia',
#  'Belicia',
#  'Belinda',
#  'Belita',
#  'Bell',
#  'Bella',
#  'Bellamy',
#  'Bellanca',
#  'Belle',
#  'Bellina',
#  'Belva',
#  'Belvia',
#  'Bendite',
#  'Benedetta',
#  'Benedicta',
#  'Benedikta',
#  'Benetta',
#  'Benita',
#  'Benni',
#  'Bennie',
#  'Benny',
#  'Benoite',
#  'Berenice',
#  'Beret',
#  'Berget',
#  'Berna',
#  'Bernadene',
#  'Bernadette',
#  'Bernadina',
#  'Bernadine',
#  'Bernardina',
#  'Bernardine',
#  'Bernelle',
#  'Bernete',
#  'Bernetta',
#  'Bernette',
#  'Berni',
#  'Bernice',
#  'Bernie',
#  'Bernita',
#  'Berny',
#  'Berri',
#  'Berrie',
#  'Berry',
#  'Bert',
#  'Berta',
#  'Berte',
#  'Bertha',
#  'Berthe',
#  'Berti',
#  'Bertie',
#  'Bertina',
#  'Bertine',
#  'Berty',
#  'Beryl',
#  'Beryle',
#  'Bess',
#  'Bessie',
#  'Bessy',
#  'Beth',
#  'Bethanne',
#  'Bethany',
#  'Bethena',
#  'Bethina',
#  'Betsey',
#  'Betsy',
#  'Betta',
#  'Bette',
#  'Bette-Ann',
#  'Betteann',
#  'Betteanne',
#  'Betti',
#  'Bettie',
#  'Bettina',
#  'Bettine',
#  'Betty',
#  'Bettye',
#  'Beulah',
#  'Bev',
#  'Beverie',
#  'Beverlee',
#  'Beverlie',
#  'Beverly',
#  'Bevvy',
#  'Bianca',
#  'Bianka',
#  'Biddy',
#  'Bidget',
#  'Bill',
#  'Billi',
#  'Billie',
#  'Billy',
#  'Binni',
#  'Binnie',
#  'Binny',
#  'Bird',
#  'Birdie',
#  'Birgit',
#  'Birgitta',
#  'Blair',
#  'Blaire',
#  'Blake',
#  'Blakelee',
#  'Blakeley',
#  'Blanca',
#  'Blanch',
#  'Blancha',
#  'Blanche',
#  'Blinni',
#  'Blinnie',
#  'Blinny',
#  'Bliss',
#  'Blisse',
#  'Blithe',
#  'Blondell',
#  'Blondelle',
#  'Blondie',
#  'Blondy',
#  'Blythe',
#  'Bo',
#  'Bobbette',
#  'Bobbi',
#  'Bobbie',
#  'Bobby',
#  'Bobette',
#  'Bobina',
#  'Bobine',
#  'Bobinette',
#  'Bonita',
#  'Bonnee',
#  'Bonni',
#  'Bonnie',
#  'Bonny',
#  'Brana',
#  'Brandais',
#  'Brande',
#  'Brandea',
#  'Brandi',
#  'Brandice',
#  'Brandie',
#  'Brandise',
#  'Brandy',
#  'Brea',
#  'Breanne',
#  'Brear',
#  'Bree',
#  'Breena',
#  'Bren',
#  'Brena',
#  'Brenda',
#  'Brenn',
#  'Brenna',
#  'Brett',
#  'Bria',
#  'Briana',
#  'Brianna',
#  'Brianne',
#  'Bride',
#  'Bridget',
#  'Bridgett',
#  'Bridgette',
#  'Bridie',
#  'Brier',
#  'Brietta',
#  'Brigid',
#  'Brigida',
#  'Brigit',
#  'Brigitta',
#  'Brigitte',
#  'Brina',
#  'Briney',
#  'Briny',
#  'Brit',
#  'Brita',
#  'Britaney',
#  'Britani',
#  'Briteny',
#  'Britney',
#  'Britni',
#  'Britt',
#  'Britta',
#  'Brittan',
#  'Brittany',
#  'Britte',
#  'Brittney',
#  'Brook',
#  'Brooke',
#  'Brooks',
#  'Brunella',
#  'Brunhilda',
#  'Brunhilde',
#  'Bryana',
#  'Bryn',
#  'Bryna',
#  'Brynn',
#  'Brynna',
#  'Brynne',
#  'Buffy',
#  'Bunni',
#  'Bunnie',
#  'Bunny',
#  'Burta',
#  'Cabrina',
#  'Cacilia',
#  'Cacilie',
#  'Caitlin',
#  'Caitrin',
#  'Cal',
#  'Calida',
#  'Calla',
#  'Calley',
#  'Calli',
#  'Callida',
#  'Callie',
#  'Cally',
#  'Calypso',
#  'Cam',
#  'Camala',
#  'Camel',
#  'Camella',
#  'Camellia',
#  'Cameo',
#  'Cami',
#  'Camila',
#  'Camile',
#  'Camilla',
#  'Camille',
#  'Cammi',
#  'Cammie',
#  'Cammy',
#  'Canada',
#  'Candace',
#  'Candi',
#  'Candice',
#  'Candida',
#  'Candide',
#  'Candie',
#  'Candis',
#  'Candra',
#  'Candy',
#  'Cappella',
#  'Caprice',
#  'Cara',
#  'Caralie',
#  'Caren',
#  'Carena',
#  'Caresa',
#  'Caressa',
#  'Caresse',
#  'Carey',
#  'Cari',
#  'Caria',
#  'Carie',
#  'Caril',
#  'Carilyn',
#  'Carin',
#  'Carina',
#  'Carine',
#  'Cariotta',
#  'Carissa',
#  'Carita',
#  'Caritta',
#  'Carla',
#  'Carlee',
#  'Carleen',
#  'Carlen',
#  'Carlena',
#  'Carlene',
#  'Carley',
#  'Carli',
#  'Carlie',
#  'Carlin',
#  'Carlina',
#  'Carline',
#  'Carlisle',
#  'Carlita',
#  'Carlota',
#  'Carlotta',
#  'Carly',
#  'Carlye',
#  'Carlyn',
#  'Carlynn',
#  'Carlynne',
#  'Carma',
#  'Carmel',
#  'Carmela',
#  'Carmelia',
#  'Carmelina',
#  'Carmelita',
#  'Carmella',
#  'Carmelle',
#  'Carmen',
#  'Carmina',
#  'Carmine',
#  'Carmita',
#  'Carmon',
#  'Caro',
#  'Carol',
#  'Carol-Jean',
#  'Carola',
#  'Carolan',
#  'Carolann',
#  'Carole',
#  'Carolee',
#  'Caroleen',
#  'Carolie',
#  'Carolin',
#  'Carolina',
#  'Caroline',
#  'Caroljean',
#  'Carolyn',
#  'Carolyne',
#  'Carolynn',
#  'Caron',
#  'Carree',
#  'Carri',
#  'Carrie',
#  'Carrissa',
#  'Carrol',
#  'Carroll',
#  'Carry',
#  'Cary',
#  'Caryl',
#  'Caryn',
#  'Casandra',
#  'Casey',
#  'Casi',
#  'Casia',
#  'Casie',
#  'Cass',
#  'Cassandra',
#  'Cassandre',
#  'Cassandry',
#  'Cassaundra',
#  'Cassey',
#  'Cassi',
#  'Cassie',
#  'Cassondra',
#  'Cassy',
#  'Cat',
#  'Catarina',
#  'Cate',
#  'Caterina',
#  'Catha',
#  'Catharina',
#  'Catharine',
#  'Cathe',
#  'Cathee',
#  'Catherin',
#  'Catherina',
#  'Catherine',
#  'Cathi',
#  'Cathie',
#  'Cathleen',
#  'Cathlene',
#  'Cathrin',
#  'Cathrine',
#  'Cathryn',
#  'Cathy',
#  'Cathyleen',
#  'Cati',
#  'Catie',
#  'Catina',
#  'Catlaina',
#  'Catlee',
#  'Catlin',
#  'Catrina',
#  'Catriona',
#  'Caty',
#  'Cayla',
#  'Cecelia',
#  'Cecil',
#  'Cecile',
#  'Ceciley',
#  'Cecilia',
#  'Cecilla',
#  'Cecily',
#  'Ceil',
#  'Cele',
#  'Celene',
#  'Celesta',
#  'Celeste',
#  'Celestia',
#  'Celestina',
#  'Celestine',
#  'Celestyn',
#  'Celestyna',
#  'Celia',
#  'Celie',
#  'Celina',
#  'Celinda',
#  'Celine',
#  'Celinka',
#  'Celisse',
#  'Celle',
#  'Cesya',
#  'Chad',
#  'Chanda',
#  'Chandal',
#  'Chandra',
#  'Channa',
#  'Chantal',
#  'Chantalle',
#  'Charil',
#  'Charin',
#  'Charis',
#  'Charissa',
#  'Charisse',
#  'Charita',
#  'Charity',
#  'Charla',
#  'Charlean',
#  'Charleen',
#  'Charlena',
#  'Charlene',
#  'Charline',
#  'Charlot',
#  'Charlott',
#  'Charlotta',
#  'Charlotte',
#  'Charmain',
#  'Charmaine',
#  'Charmane',
#  'Charmian',
#  'Charmine',
#  'Charmion',
#  'Charo',
#  'Charyl',
#  'Chastity',
#  'Chelsae',
#  'Chelsea',
#  'Chelsey',
#  'Chelsie',
#  'Chelsy',
#  'Cher',
#  'Chere',
#  'Cherey',
#  'Cheri',
#  'Cherianne',
#  'Cherice',
#  'Cherida',
#  'Cherie',
#  'Cherilyn',
#  'Cherilynn',
#  'Cherin',
#  'Cherise',
#  'Cherish',
#  'Cherlyn',
#  'Cherri',
#  'Cherrita',
#  'Cherry',
#  'Chery',
#  'Cherye',
#  'Cheryl',
#  'Cheslie',
#  'Chiarra',
#  'Chickie',
#  'Chicky',
#  'Chiquita',
#  'Chloe',
#  'Chloette',
#  'Chloris',
#  'Chris',
#  'Chriss',
#  'Chrissa',
#  'Chrissie',
#  'Chrissy',
#  'Christa',
#  'Christabel',
#  'Christabella',
#  'Christabelle',
#  'Christal',
#  'Christalle',
#  'Christan',
#  'Christean',
#  'Christel',
#  'Christen',
#  'Christi',
#  'Christian',
#  'Christiana',
#  'Christiane',
#  'Christie',
#  'Christin',
#  'Christina',
#  'Christine',
#  'Christy',
#  'Christyna',
#  'Chrysa',
#  'Chrysler',
#  'Chrystal',
#  'Chryste',
#  'Chrystel',
#  'Ciara',
#  'Cicely',
#  'Cicily',
#  'Ciel',
#  'Cilka',
#  'Cinda',
#  'Cindee',
#  'Cindelyn',
#  'Cinderella',
#  'Cindi',
#  'Cindie',
#  'Cindra',
#  'Cindy',
#  'Cinnamon',
#  'Cissie',
#  'Cissy',
#  'Clair',
#  'Claire',
#  'Clara',
#  'Clarabelle',
#  'Clare',
#  ...]
